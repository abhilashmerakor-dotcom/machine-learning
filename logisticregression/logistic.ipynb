# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(penalty='l1')
'''1) penalty: Literal['l1', 'l2', 'elasticnet'] | None = "l2",
model = LogisticRegression(penalty='l1')
model = LogisticRegression(penalty='l2')
model = LogisticRegression(penalty='elasticnet')
2)solver : it is an optimization engine which helps gradient descent to optimize the weights default solver :  "lbfgs" 
solver: Literal['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'] = "lbfgs", always its support l2.
3)max_iter: Int = 100, maximumum no of iteration taken solver to conver  it acces only integer by default it will take 100
4)class_weight : here we can use two vallues none or balance  
this is use when data st imbalance we can use clas weight 
how to find data set is imbalens ? ans: based target coloumn we can find  count of the unique value target coloumn is equal it is balance ex(450,550)
imbalance data set target coliumn = 700,450
solution is 1)class_weight = balanced,  parameter in logistic regression
            2) re_sampling 
5)C: Float = 1, here we can few values 1,1000 like that the see parametr is descide the module is going underfit, over fit, good fit, '''

# %% [markdown]
# sag and saga : when we have have more fetures on that
# wher we get more fetures? sentence bese classification we got more fetaures

# %% [markdown]
# # solver	  ,          l1_ratio	      ,        multinomial multiclass
# 'lbfgs'	            l1_ratio=0	                        yes
# 'liblinear'     	l1_ratio=1 or l1_ratio=0	        no
# 'newton-cg'	        l1_ratio=0	                        yes
# 'newton-cholesky'	l1_ratio=0	                        yes
# 'sag'	            l1_ratio=0	                        yes
# 'saga'	            0<=l1_ratio<=1	                    yes

# %% [markdown]
# tolerance:  helpes grdient descent to stop the iteration gradient descent best weight
